# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullaahiyow/Ecommerce-website-with-React/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Dataset/real_estate_price_size.csv')
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
y = (data.price)
y
# Out:
# 0     234314.144
# 1     228581.528
# 2     281626.336
# 3     401255.608
# 4     458674.256
#          ...
# 95    252460.400
# 96    310522.592
# 97    383635.568
# 98    225145.248
# 99    274922.856
# Name: price, Length: 100, dtype: float64
